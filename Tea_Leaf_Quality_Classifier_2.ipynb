# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
yolo = YOLO('yolo12s.pt')
# Out:
# ...
# 100%|██████████| 18.1M/18.1M [00:00<00:00, 137MB/s]

# %%
# # Unzip the file
# import os
# import shutil
# import zipfile # Added import for zipfile as it was missing in this cell

# # Define the destination directory
# destination_dir = "/content/Tea_Leaf_Quality_Data_Set"

# # Remove the destination directory if it exists
# if os.path.exists(destination_dir):
#     # Check if it's a directory before attempting rmtree
#     if os.path.isdir(destination_dir):
#         shutil.rmtree(destination_dir)
#     else:
#         # If it's a file, remove the file
#         os.remove(destination_dir)

# # Create the destination directory
# os.makedirs(destination_dir)

# with zipfile.ZipFile("/content/TeaLeafAgeQuality.zip", 'r') as zip_ref:
#     zip_ref.extractall(destination_dir)

# %%
# !yolo task=detect mode=train model=yolo12s.pt data=/content/Tea_Leaf_Quality_Data_Set/TeaLeafAgeQuality/data.yaml epochs=101 imgsz=640
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/Tea_Leaf_Quality_Data_Set/TeaLeafAgeQuality/data.yaml
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5 source=data=/content/Tea_Leaf_Quality_Data_Set/TeaLeafAgeQuality/test/images/ save=True
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,415,896 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/406 /content/Tea_Leaf_Disease_Data_Set/test/images/IMG_0159_JPG_jpg.rf.1e3e1970ffdcdf54522d3d64749487c2.jpg: 640x640 2 Tea Mosquito bug infested leafs, 15.9ms
# image 2/406 /content/Tea_Leaf_Disease_Data_Set/test/images/IMG_0180_JPG_jpg.rf.57df9326a7886ea5de4d3c3d83c4ae8b.jpg: 640x640 2 Red Spider infested tea leafs, 15.7ms
# image 3/406 /content/Tea_Leaf_Disease_Data_Set/test/images/IMG_0184_JPG_jpg.rf.9b2b088ae8aec817e65f18fcadb93518.jpg: 640x640 2 Red Spider infested tea leafs, 15.6ms
# image 4/406 /content/Tea_Leaf_Disease_Data_Set/test/images/IMG_0187_JPG_jpg.rf.aff9602b089e76981453087525dcb081.jpg: 640x640 2 Red Spider infested tea leafs, 15.6ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display
latest_folder=max(glob.iglob('/content/runs/detect/predict*'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
  display(IPyImage(filename=img))
  print('\n')

# %%
# !zip -r /content/yolo_model_runs.zip /content/runs

# %%
# from google.colab import files
# files.download("/content/yolo_model_runs.zip")

# %%
# path = r"/content/VID20250514164746.mp4"
# results = yolo(path,save=True)
# results[0].show()

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5 source=/content/my_testing_data_set/ save=True imgsz= 3072,4096
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,415,896 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/2 /content/my_testing_data_set/t_img_0.jpeg: 3072x2304 3 Leaf rust of teas, 9 Tea Mosquito bug infested leafs, 153.2ms
# image 2/2 /content/my_testing_data_set/t_img_1.jpeg: 3072x2304 1 Red Spider infested tea leaf, 9 Tea Mosquito bug infested leafs, 152.7ms
# Speed: 88.0ms preprocess, 153.0ms inference, 85.1ms postprocess per image at shape (1, 3, 3072, 2304)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
files.download("/content/runs/detect/predict2/VID20250514164746.avi")
